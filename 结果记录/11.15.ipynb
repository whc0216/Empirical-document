# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1', 'past_experience', 'From', 'internet','year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

regression = smf.ols(formula='Efficiency1 ~ past_experience*internet+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience','past_experience:internet',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                          Efficiency1
# ------------------------------------
# Intercept                0.8546**
#                          (0.3332)
# past_experience          0.0999***
#                          (0.0276)
# past_experience:internet 0.0924*
#                          (0.0535)
# male                     -0.0078
#                          (0.0151)
# age                      -0.0016
#                          (0.0011)
# education                -0.0135
#                          (0.0093)
# industry_structure       -0.0405
#                          (0.0867)
# Fiscal_autonomy          -0.0032
#                          (0.0502)
# population_log           0.0355
#                          (0.1291)
# perGDP_log               0.0400
#                          (0.0484)
# R-squared                0.1798
# R-squared Adj.           0.0339
# Observations             1922
# ...
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# 人大预算联网监督 正向显著

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1', 'past_experience', 'From', 'year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

data_c['law_dummy']=(data_c['year']>=2016).astype(int)

regression = smf.ols(formula='Efficiency1 ~ past_experience*law_dummy+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience','past_experience:law_dummy',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                           Efficiency1
# -------------------------------------
# Intercept                 0.8474**
#                           (0.3323)
# past_experience           0.0648*
#                           (0.0351)
# past_experience:law_dummy 0.0982**
#                           (0.0445)
# male                      -0.0080
#                           (0.0151)
# age                       -0.0017
#                           (0.0011)
# education                 -0.0146
#                           (0.0093)
# industry_structure        -0.0186
#                           (0.0861)
# Fiscal_autonomy           -0.0046
#                           (0.0502)
# population_log            0.0545
#                           (0.1293)
# perGDP_log                0.0326
#                           (0.0483)
# R-squared                 0.1775
# R-squared Adj.            0.0319
# Observations              1922
# ...
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# 这个考虑16年营增改 显示16年之后效果更好

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1', 'past_experience', 'From','btshare2011_after2016' ,'year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

data_c['law_dummy']=(data_c['year']>=2016).astype(int)

regression = smf.ols(formula='Efficiency1 ~ past_experience*btshare2011_after2016+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience','btshare2011_after2016','past_experience:btshare2011_after2016',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                                       Efficiency1
# -------------------------------------------------
# Intercept                             0.7404**
#                                       (0.3378)
# past_experience                       0.0732**
#                                       (0.0331)
# btshare2011_after2016                 -0.0878
#                                       (0.0692)
# past_experience:btshare2011_after2016 0.4023**
#                                       (0.1907)
# male                                  -0.0086
#                                       (0.0151)
# age                                   -0.0016
#                                       (0.0011)
# education                             -0.0152
#                                       (0.0093)
# industry_structure                    -0.0173
#                                       (0.0862)
# Fiscal_autonomy                       -0.0034
#                                       (0.0503)
# ...

# %% [markdown]
# 但是这个跑完我在想一个问题 这个16年之后更好的效果有多少来自营增改的影响
# 于是我加入了数字化那篇对应增改程度衡量的代理变量

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1', 'past_experience', 'From', 'year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

data_c['age_dummy']=(data_c['age']<=57).astype(int)

regression = smf.ols(formula='Efficiency1 ~ past_experience*age_dummy+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience','past_experience:age_dummy',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                           Efficiency1
# -------------------------------------
# Intercept                 0.8268**
#                           (0.3348)
# past_experience           -0.0406
#                           (0.0632)
# past_experience:age_dummy 0.1826***
#                           (0.0665)
# male                      -0.0079
#                           (0.0151)
# age                       -0.0016
#                           (0.0013)
# education                 -0.0129
#                           (0.0093)
# industry_structure        -0.0176
#                           (0.0861)
# Fiscal_autonomy           -0.0103
#                           (0.0502)
# population_log            0.0438
#                           (0.1291)
# perGDP_log                0.0417
#                           (0.0482)
# R-squared                 0.1789
# R-squared Adj.            0.0329
# Observations              1922
# ...
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# 年龄 57岁之前更愿意做

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1', 'past_experience','importance', 'From', 'year','wide_d_lead','strict_d','strict_d_lead','word_time', 'city','word_time_province_narrow','strict_wide_d', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

regression = smf.ols(formula='Efficiency1 ~ past_experience*word_time+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience','past_experience:word_time',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                           Efficiency1
# -------------------------------------
# Intercept                 0.8296**
#                           (0.3330)
# past_experience           0.1206***
#                           (0.0274)
# past_experience:word_time -0.0031
#                           (0.0340)
# male                      -0.0077
#                           (0.0151)
# age                       -0.0017
#                           (0.0011)
# education                 -0.0149
#                           (0.0093)
# industry_structure        -0.0125
#                           (0.0863)
# Fiscal_autonomy           -0.0117
#                           (0.0503)
# population_log            0.0444
#                           (0.1294)
# perGDP_log                0.0405
#                           (0.0483)
# R-squared                 0.1762
# R-squared Adj.            0.0297
# Observations              1922
# ...
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# 省级词频与地级市词频的效果一直不好

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1', 'past_experience', 'From','btshare2011_after2016' ,'budget_index_2014_After_2015','year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

data_c['law_dummy']=(data_c['year']>=2015).astype(int)

regression = smf.ols(formula='Efficiency1 ~ past_experience*budget_index_2014_After_2015+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience','past_experience:law_dummy','budget_index_2014_After_2015','past_experience:budget_index_2014_After_2015',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                                              Efficiency1
# --------------------------------------------------------
# Intercept                                    0.8471**
#                                              (0.3329)
# past_experience                              0.1180***
#                                              (0.0422)
# budget_index_2014_After_2015                 0.0004
#                                              (0.0006)
# past_experience:budget_index_2014_After_2015 0.0000
#                                              (0.0007)
# male                                         -0.0084
#                                              (0.0151)
# age                                          -0.0017
#                                              (0.0011)
# education                                    -0.0151
#                                              (0.0093)
# industry_structure                           -0.0242
# ...

# %% [markdown]
# 预算管理规范程度与预算法2015

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1', 'past_experience','Budget_performance' ,'From','btshare2011_after2016' ,'budget_index_2014_After_2015','year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

data_c['law_dummy']=(data_c['year']>=2015).astype(int)

regression = smf.ols(formula='Efficiency1 ~ past_experience*Budget_performance+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience','past_experience:law_dummy','Budget_performance','past_experience:Budget_performance',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                                    Efficiency1
# ----------------------------------------------
# Intercept                          0.8077**
#                                    (0.3404)
# past_experience                    0.1445**
#                                    (0.0632)
# Budget_performance                 0.0067
#                                    (0.0123)
# past_experience:Budget_performance -0.0300
#                                    (0.0675)
# male                               -0.0082
#                                    (0.0151)
# age                                -0.0017
#                                    (0.0011)
# education                          -0.0152
#                                    (0.0093)
# industry_structure                 -0.0150
#                                    (0.0866)
# Fiscal_autonomy                    -0.0108
#                                    (0.0503)
# population_log                     0.0493
# ...

# %% [markdown]
# 《预算绩效评价管理办法》

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1', 'past_experience','Budget_performance','Audit' ,'From','btshare2011_after2016' ,'budget_index_2014_After_2015','year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

data_c['law_dummy']=(data_c['year']>=2015).astype(int)

regression = smf.ols(formula='Efficiency1 ~ past_experience*Audit+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience','Audit','past_experience:Audit',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                       Efficiency1
# ---------------------------------
# Intercept             0.8177**
#                       (0.3342)
# past_experience       0.1197***
#                       (0.0268)
# Audit                 -0.0126
#                       (0.0123)
# past_experience:Audit -0.0033
#                       (0.0696)
# male                  -0.0081
#                       (0.0151)
# age                   -0.0017
#                       (0.0011)
# education             -0.0155*
#                       (0.0093)
# industry_structure    -0.0025
#                       (0.0876)
# Fiscal_autonomy       -0.0123
#                       (0.0503)
# population_log        0.0566
#                       (0.1305)
# perGDP_log            0.0371
#                       (0.0484)
# R-squared             0.1756
# R-squared Adj.        0.0290
# Observations          1922
# ...
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# 2015 年在江苏、浙江、山东、广东、重庆、贵州、云南 7 省的审计体制改革

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1', 'past_experience','Budget_performance','Anti_corruption','Audit' ,'From','btshare2011_after2016' ,'budget_index_2014_After_2015','year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

data_c['law_dummy']=(data_c['year']>=2015).astype(int)

regression = smf.ols(formula='Efficiency1 ~ past_experience*Anti_corruption+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience','Anti_corruption','past_experience:Anti_corruption',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                                 Efficiency1
# -------------------------------------------
# Intercept                       0.8463**
#                                 (0.3333)
# past_experience                 0.1727**
#                                 (0.0816)
# Anti_corruption                 -0.0071
#                                 (0.0138)
# past_experience:Anti_corruption -0.0584
#                                 (0.0830)
# male                            -0.0085
#                                 (0.0151)
# age                             -0.0016
#                                 (0.0011)
# education                       -0.0152
#                                 (0.0093)
# industry_structure              -0.0226
#                                 (0.0864)
# Fiscal_autonomy                 -0.0093
#                                 (0.0503)
# population_log                  0.0332
#                                 (0.1295)
# perGDP_log                      0.0432
# ...

# %% [markdown]
# 纪委巡视

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1','Efficiency1_SFA','past_experience', 'past_experience_SFA','Budget_performance','Anti_corruption','Audit' ,'From','btshare2011_after2016' ,'budget_index_2014_After_2015','year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

regression = smf.ols(formula='Efficiency1_SFA ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience_SFA','past_experience','past_experience:Anti_corruption',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                    Efficiency1_SFA
# ----------------------------------
# Intercept          -2.7401***
#                    (0.3990)
# past_experience    0.1129***
#                    (0.0302)
# male               -0.0163
#                    (0.0181)
# age                0.0028**
#                    (0.0013)
# education          0.0186*
#                    (0.0111)
# industry_structure 0.4353***
#                    (0.1034)
# Fiscal_autonomy    -0.1047*
#                    (0.0603)
# population_log     1.3611***
#                    (0.1551)
# perGDP_log         0.1058*
#                    (0.0579)
# R-squared          0.4088
# R-squared Adj.     0.3047
# Observations       1925
# ...
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# 替换y估计方法

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1','Efficiency1_SFA','Edu','WG_ZB','SFJG','pro_1to11','pro_1to11_num','Tec','Sec','Med','Investment','Pubservice','past_experience', 'past_experience_SFA','Budget_performance','Anti_corruption','Audit' ,'From','btshare2011_after2016' ,'budget_index_2014_After_2015','year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

regression1 = smf.ols(formula='WG_ZB ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg1 = regression1.fit()

regression2 = smf.ols(formula='SFJG ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg2 = regression2.fit()

regression3 = smf.ols(formula='pro_1to11 ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg3 = regression3.fit()

regression4 = smf.ols(formula='pro_1to11_num ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg4 = regression4.fit()

regression5 = smf.ols(formula='Tec ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg5 = regression5.fit()

regression6 = smf.ols(formula='Sec ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg6 = regression6.fit()

regression7 = smf.ols(formula='Med ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg7 = regression7.fit()

regression8 = smf.ols(formula='Investment ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg8 = regression8.fit()

regression9 = smf.ols(formula='Pubservice ~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg9 = regression9.fit()

regression10 = smf.ols(formula='Edu~ past_experience+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg10 = regression10.fit()

result=summary_col([result_reg1,result_reg2,result_reg3,result_reg4,result_reg5,result_reg6,result_reg7,result_reg8,result_reg9,result_reg10],
                   stars=True,
                   model_names=['WG_ZB','SFJG','pro_1to11','pro_1to11_num','Tec','Sec','Med','Investment','Pubservice','Edu'],
                   regressor_order=['Intercept','past_experience_SFA','past_experience','past_experience:Anti_corruption',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                     WG_ZB      SFJG   pro_1to11 pro_1to11_num    Tec        Sec        Med     Investment Pubservice    Edu
# -------------------------------------------------------------------------------------------------------------------------------
# Intercept          1.7516*  2.5971*** 1.2077    1.6822***     -0.1337*** 0.6463***  -0.0824*** -0.1148    0.0779*    -0.1261***
#                    (0.9151) (0.7381)  (0.8294)  (0.4069)      (0.0188)   (0.0561)   (0.0303)   (0.2034)   (0.0418)   (0.0405)
# past_experience    0.0712   -0.0611   0.1558*** 0.0378        0.0029**   -0.0061    -0.0039*   0.0054     -0.0021    -0.0109***
#                    (0.0693) (0.0559)  (0.0554)  (0.0272)      (0.0014)   (0.0043)   (0.0024)   (0.0154)   (0.0032)   (0.0031)
# male               -0.0358  -0.0194   -0.0710** -0.0092       -0.0009    0.0013     -0.0004    0.0061     0.0034*    0.0031*
# ...

# %% [markdown]
# 机制检验

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1','rdzr_econwork','Efficiency1_SFA','past_experience', 'past_experience_SFA','Budget_performance','Anti_corruption','Audit' ,'From','btshare2011_after2016' ,'budget_index_2014_After_2015','year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

regression = smf.ols(formula='Efficiency1 ~ past_experience*rdzr_econwork+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience_SFA','past_experience','past_experience:rdzr_econwork',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                               Efficiency1
# -----------------------------------------
# Intercept                     0.8270**
#                               (0.3326)
# past_experience               0.0847*
#                               (0.0434)
# past_experience:rdzr_econwork 0.0484
#                               (0.0511)
# male                          -0.0086
#                               (0.0151)
# age                           -0.0017
#                               (0.0011)
# education                     -0.0148
#                               (0.0093)
# industry_structure            -0.0213
#                               (0.0861)
# Fiscal_autonomy               -0.0095
#                               (0.0502)
# population_log                0.0460
#                               (0.1293)
# perGDP_log                    0.0424
#                               (0.0483)
# R-squared                     0.1758
# R-squared Adj.                0.0296
# ...

# %% [markdown]
# 人大主任是否有财经背景与审计经历

# %%
import pandas as pd
import statsmodels.formula.api as smf
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.iolib.summary2 import summary_col

data_w = pd.read_excel("C:\\Users\\王浩晨\\Desktop\\数据_支出.xlsx")
data_h = data_w[['Efficiency1','rdzr_econwork','tax_burden','Efficiency1_SFA','past_experience', 'past_experience_SFA','Budget_performance','Anti_corruption','Audit' ,'From','btshare2011_after2016' ,'budget_index_2014_After_2015','year', 'city', 'industry_structure','Fiscal_autonomy','male', 'age', 'education', 'population_log', 'perGDP_log']]
data_h = data_h.set_index(['city', 'year'], drop=False)
data_c = pd.DataFrame(data_h)

regression = smf.ols(formula='Efficiency1 ~ past_experience*tax_burden+industry_structure+Fiscal_autonomy+population_log+perGDP_log +male+age+education+ C(year) + C(city)', data=data_c)
result_reg = regression.fit()

result=summary_col(result_reg,
                   stars=True,
                   regressor_order=['Intercept','past_experience_SFA','past_experience','past_experience:tax_burden',
                                    'male', 'age', 'education', 'industry_structure',
                                   'Fiscal_autonomy', 'population_log', 'perGDP_log'],
                    drop_omitted=True,
                    info_dict={'Observations': lambda x: str(int(x.nobs))})

print(result)
# Out:
# ...
#                            Efficiency1
# --------------------------------------
# Intercept                  0.9008***
#                            (0.3352)
# past_experience            0.0785
#                            (0.0624)
# past_experience:tax_burden 0.8364
#                            (1.1463)
# male                       -0.0086
#                            (0.0151)
# age                        -0.0016
#                            (0.0011)
# education                  -0.0157*
#                            (0.0093)
# industry_structure         -0.0211
#                            (0.0861)
# Fiscal_autonomy            -0.0018
#                            (0.0507)
# population_log             0.0348
#                            (0.1293)
# perGDP_log                 0.0310
#                            (0.0488)
# R-squared                  0.1763
# R-squared Adj.             0.0301
# Observations               1925
# ...
# Standard errors in parentheses.
# * p<.1, ** p<.05, ***p<.01

# %% [markdown]
# 企业收到税费优惠 考虑减税降费的影响 结合15不显著的结果
